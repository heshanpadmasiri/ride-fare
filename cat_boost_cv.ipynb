# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score

from catboost import Pool, cv,CatBoostClassifier

# %%
train_df = pd.read_csv('train_df.csv')
test_df = pd.read_csv('test_df.csv')
submission_df = pd.read_csv('sample_submission.csv')

# %%
train_df.head()
# Out:
#    additional_fare  duration  meter_waiting  meter_waiting_fare  \
# 0             10.5     834.0           56.0              0.0000
# 1             10.5     791.0           47.0              0.0000
# 2             10.5    1087.0           80.0              0.0000
# 3             10.5     598.0          271.0             15.6638
# 4             10.5    3407.0          182.0              0.0000
#
#    meter_waiting_till_pickup     fare  pickup_date  pickup_year  pickup_hour  \
# 0                       64.0   270.32            1         2019            0
# 1                      134.0   197.85            1         2019            0
# 2                       61.0   301.64            1         2019            1
# 3                       68.0    82.30            1         2019            2
# 4                      112.0  1065.02            1         2019            5
#
#    pickup_minute  drop_date  drop_year  drop_hour  drop_minute  pick_cluster  \
# 0             20          1       2019          0           34             0
# 1             56          1       2019          1            9             0
# 2              8          1       2019          1           26             0
# 3             27          1       2019          2           37             0
# 4             38          1       2019          6           35             2
#
#    drop_cluster  label
# 0             1      1
# 1             1      1
# 2             1      1
# 3             1      1
# 4             1      1

# %%
cat_features = ['pickup_date', 'pickup_year', 'pickup_hour',
       'pickup_minute', 'drop_date', 'drop_year', 'drop_hour', 'drop_minute','pick_cluster','drop_cluster']
labels = train_df['label'].values
train_df = train_df.drop(['label'], axis=1)

# %%
skf = StratifiedKFold(n_splits=3)

# %%
params = {
    'loss_function':'Logloss',
    'random_state':0,
    'early_stopping_rounds':50,
    'eval_metric':'F1'
}

# %%
validation_scores = []

# %%
for train_index, test_index in skf.split(train_df, labels):
    X_train, X_test = train_df.iloc[train_index,:], train_df.iloc[test_index,:]
    y_train, y_test = labels[train_index], labels[test_index]
    train_pool = Pool(data=X_train, label=y_train,cat_features=cat_features)
    test_pool = Pool(data=X_test, label=y_test, cat_features=cat_features)
    
    model = CatBoostClassifier(**params)
    model.fit(X=train_pool, eval_set=test_pool,verbose=10)
    pred = model.predict(test_pool)
    validation_score = f1_score(y_test, pred, average='macro')
    print('Validation f1',validation_score)
    validation_scores.append(validation_score)
# Out:
# Learning rate set to 0.057693
# 0:	learn: 0.9529276	test: 0.9528835	best: 0.9528835 (0)	total: 10.8ms	remaining: 10.8s
# 10:	learn: 0.9580928	test: 0.9584575	best: 0.9589935 (9)	total: 191ms	remaining: 17.2s
# 20:	learn: 0.9571123	test: 0.9580114	best: 0.9589935 (9)	total: 420ms	remaining: 19.6s
# 30:	learn: 0.9592836	test: 0.9549583	best: 0.9589935 (9)	total: 652ms	remaining: 20.4s
# 40:	learn: 0.9640160	test: 0.9605499	best: 0.9607529 (39)	total: 887ms	remaining: 20.8s
# 50:	learn: 0.9649922	test: 0.9617528	best: 0.9627112 (47)	total: 1.1s	remaining: 20.5s
# 60:	learn: 0.9662054	test: 0.9563315	best: 0.9627112 (47)	total: 1.32s	remaining: 20.4s
# 70:	learn: 0.9670547	test: 0.9480158	best: 0.9627112 (47)	total: 1.56s	remaining: 20.4s
# 80:	learn: 0.9675928	test: 0.9447391	best: 0.9627112 (47)	total: 1.76s	remaining: 19.9s
# 90:	learn: 0.9683266	test: 0.9439027	best: 0.9627112 (47)	total: 1.97s	remaining: 19.7s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.9627112244
# bestIteration = 47
#
# Shrink model to first 48 iterations.
# Validation f1 0.7066685468281662
# Learning rate set to 0.057693
# 0:	learn: 0.9529276	test: 0.9528835	best: 0.9528835 (0)	total: 11.1ms	remaining: 11.1s
# 10:	learn: 0.9579222	test: 0.9564813	best: 0.9585236 (3)	total: 234ms	remaining: 21.1s
# 20:	learn: 0.9609941	test: 0.9589322	best: 0.9589322 (20)	total: 414ms	remaining: 19.3s
# 30:	learn: 0.9630462	test: 0.9612432	best: 0.9612432 (30)	total: 643ms	remaining: 20.1s
# 40:	learn: 0.9652452	test: 0.9636586	best: 0.9636586 (40)	total: 855ms	remaining: 20s
# 50:	learn: 0.9670588	test: 0.9643732	best: 0.9644536 (45)	total: 1.09s	remaining: 20.3s
# 60:	learn: 0.9674441	test: 0.9649057	best: 0.9651009 (59)	total: 1.32s	remaining: 20.3s
# 70:	learn: 0.9687987	test: 0.9657974	best: 0.9657974 (69)	total: 1.56s	remaining: 20.4s
# 80:	learn: 0.9693906	test: 0.9656802	best: 0.9657974 (69)	total: 1.93s	remaining: 22s
# 90:	learn: 0.9696511	test: 0.9658629	best: 0.9658629 (87)	total: 2.2s	remaining: 22s
# 100:	learn: 0.9701528	test: 0.9653540	best: 0.9661370 (95)	total: 2.43s	remaining: 21.7s
# 110:	learn: 0.9709877	test: 0.9649223	best: 0.9661370 (95)	total: 2.64s	remaining: 21.2s
# 120:	learn: 0.9713988	test: 0.9648108	best: 0.9661370 (95)	total: 2.88s	remaining: 20.9s
# 130:	learn: 0.9718130	test: 0.9646144	best: 0.9661370 (95)	total: 3.1s	remaining: 20.5s
# 140:	learn: 0.9722275	test: 0.9638989	best: 0.9661370 (95)	total: 3.33s	remaining: 20.3s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.9661369656
# bestIteration = 95
#
# Shrink model to first 96 iterations.
# Validation f1 0.7411765908928225
# Learning rate set to 0.057694
# 0:	learn: 0.9638882	test: 0.9568000	best: 0.9568000 (0)	total: 27.4ms	remaining: 27.4s
# 10:	learn: 0.9570273	test: 0.9543853	best: 0.9582712 (5)	total: 243ms	remaining: 21.8s
# 20:	learn: 0.9602838	test: 0.9554400	best: 0.9582712 (5)	total: 427ms	remaining: 19.9s
# 30:	learn: 0.9639809	test: 0.9570153	best: 0.9582712 (5)	total: 648ms	remaining: 20.3s
# 40:	learn: 0.9654200	test: 0.9585159	best: 0.9585159 (40)	total: 865ms	remaining: 20.2s
# 50:	learn: 0.9664095	test: 0.9590447	best: 0.9592237 (46)	total: 1.09s	remaining: 20.2s
# 60:	learn: 0.9683079	test: 0.9603738	best: 0.9603738 (60)	total: 1.33s	remaining: 20.5s
# 70:	learn: 0.9696225	test: 0.9607330	best: 0.9610025 (66)	total: 1.54s	remaining: 20.2s
# 80:	learn: 0.9700695	test: 0.9610924	best: 0.9610924 (75)	total: 1.77s	remaining: 20.1s
# 90:	learn: 0.9705200	test: 0.9616249	best: 0.9616249 (90)	total: 2s	remaining: 20s
# 100:	learn: 0.9708012	test: 0.9614521	best: 0.9617149 (95)	total: 2.2s	remaining: 19.6s
# 110:	learn: 0.9712094	test: 0.9616392	best: 0.9617149 (95)	total: 2.44s	remaining: 19.6s
# 120:	learn: 0.9720866	test: 0.9618192	best: 0.9618192 (117)	total: 2.69s	remaining: 19.5s
# 130:	learn: 0.9726885	test: 0.9619092	best: 0.9619092 (127)	total: 2.9s	remaining: 19.2s
# 140:	learn: 0.9732012	test: 0.9617292	best: 0.9619993 (133)	total: 3.14s	remaining: 19.1s
# 150:	learn: 0.9736555	test: 0.9619993	best: 0.9619993 (133)	total: 3.34s	remaining: 18.8s
# 160:	learn: 0.9737991	test: 0.9620964	best: 0.9620964 (154)	total: 3.62s	remaining: 18.8s
# 170:	learn: 0.9742104	test: 0.9620893	best: 0.9620964 (154)	total: 4s	remaining: 19.4s
# 180:	learn: 0.9747220	test: 0.9620893	best: 0.9620964 (154)	total: 4.34s	remaining: 19.6s
# 190:	learn: 0.9755193	test: 0.9621723	best: 0.9622695 (181)	total: 4.65s	remaining: 19.7s
# 200:	learn: 0.9759368	test: 0.9621581	best: 0.9622695 (181)	total: 4.94s	remaining: 19.6s
# 210:	learn: 0.9764454	test: 0.9626089	best: 0.9626089 (208)	total: 5.22s	remaining: 19.5s
# 220:	learn: 0.9768195	test: 0.9624215	best: 0.9626089 (208)	total: 5.51s	remaining: 19.4s
# 230:	learn: 0.9770033	test: 0.9622412	best: 0.9626089 (208)	total: 5.83s	remaining: 19.4s
# 240:	learn: 0.9774708	test: 0.9624215	best: 0.9626089 (208)	total: 6.14s	remaining: 19.3s
# 250:	learn: 0.9777058	test: 0.9625117	best: 0.9626089 (208)	total: 6.44s	remaining: 19.2s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.9626089401
# bestIteration = 208
#
# Shrink model to first 209 iterations.
# Validation f1 0.6690978972890854

# %%
np.mean(validation_scores), np.std(validation_scores)
# Out:
# (0.7056476783366913, 0.02943485629049361)
