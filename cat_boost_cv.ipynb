# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score

from catboost import Pool, cv,CatBoostClassifier

# %%
train_df = pd.read_csv('train_df.csv')
test_df = pd.read_csv('test_df.csv')
submission_df = pd.read_csv('sample_submission.csv')

# %%
train_df.head()
# Out:
#    additional_fare  duration  meter_waiting  meter_waiting_fare  \
# 0             10.5     834.0           56.0              0.0000
# 1             10.5     791.0           47.0              0.0000
# 2             10.5    1087.0           80.0              0.0000
# 3             10.5     598.0          271.0             15.6638
# 4             10.5    3407.0          182.0              0.0000
#
#    meter_waiting_till_pickup     fare  pickup_date  pickup_year  pickup_hour  \
# 0                       64.0   270.32            1         2019            0
# 1                      134.0   197.85            1         2019            0
# 2                       61.0   301.64            1         2019            1
# 3                       68.0    82.30            1         2019            2
# 4                      112.0  1065.02            1         2019            5
#
#    pickup_minute  drop_date  drop_year  drop_hour  drop_minute  pick_cluster  \
# 0             20          1       2019          0           34             3
# 1             56          1       2019          1            9             3
# 2              8          1       2019          1           26             3
# 3             27          1       2019          2           37             3
# 4             38          1       2019          6           35             0
#
#    label
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
cat_features = ['pickup_date', 'pickup_year', 'pickup_hour',
       'pickup_minute', 'drop_date', 'drop_year', 'drop_hour', 'drop_minute','pick_cluster']
labels = train_df['label'].values
train_df = train_df.drop(['label'], axis=1)

# %%
skf = StratifiedKFold(n_splits=3)

# %%
params = {
    'loss_function':'Logloss',
    'random_state':0,
    'early_stopping_rounds':50,
    'eval_metric':'F1'
}

# %%
validation_scores = []

# %%
for train_index, test_index in skf.split(train_df, labels):
    X_train, X_test = train_df.iloc[train_index,:], train_df.iloc[test_index,:]
    y_train, y_test = labels[train_index], labels[test_index]
    train_pool = Pool(data=X_train, label=y_train,cat_features=cat_features)
    test_pool = Pool(data=X_test, label=y_test, cat_features=cat_features)
    
    model = CatBoostClassifier(**params)
    model.fit(X=train_pool, eval_set=test_pool,verbose=10)
    pred = model.predict(test_pool)
    validation_score = f1_score(y_test, pred, average='macro')
    print('Validation f1',validation_score)
    validation_scores.append(validation_score)
# Out:
# Learning rate set to 0.057693
# 0:	learn: 0.9578992	test: 0.9586792	best: 0.9586792 (0)	total: 19.2ms	remaining: 19.2s
# 10:	learn: 0.9577806	test: 0.9594481	best: 0.9610390 (2)	total: 209ms	remaining: 18.8s
# 20:	learn: 0.9579996	test: 0.9593435	best: 0.9610390 (2)	total: 458ms	remaining: 21.3s
# 30:	learn: 0.9607440	test: 0.9601650	best: 0.9611823 (27)	total: 711ms	remaining: 22.2s
# 40:	learn: 0.9639707	test: 0.9602568	best: 0.9611823 (27)	total: 996ms	remaining: 23.3s
# 50:	learn: 0.9653163	test: 0.9586495	best: 0.9612769 (43)	total: 1.27s	remaining: 23.7s
# 60:	learn: 0.9662668	test: 0.9562238	best: 0.9612769 (43)	total: 1.54s	remaining: 23.8s
# 70:	learn: 0.9672100	test: 0.9515326	best: 0.9612769 (43)	total: 1.83s	remaining: 23.9s
# 80:	learn: 0.9676629	test: 0.9460709	best: 0.9612769 (43)	total: 2.09s	remaining: 23.7s
# 90:	learn: 0.9687131	test: 0.9462013	best: 0.9612769 (43)	total: 2.38s	remaining: 23.7s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.9612769173
# bestIteration = 43
#
# Shrink model to first 44 iterations.
# Validation f1 0.6982693126269044
# Learning rate set to 0.057694
# 0:	learn: 0.9537403	test: 0.9507953	best: 0.9507953 (0)	total: 27.4ms	remaining: 27.4s
# 10:	learn: 0.9540800	test: 0.9529543	best: 0.9543684 (1)	total: 274ms	remaining: 24.7s
# 20:	learn: 0.9621697	test: 0.9610778	best: 0.9610778 (20)	total: 571ms	remaining: 26.6s
# 30:	learn: 0.9636432	test: 0.9621368	best: 0.9621368 (30)	total: 859ms	remaining: 26.8s
# 40:	learn: 0.9654265	test: 0.9639233	best: 0.9639301 (37)	total: 1.16s	remaining: 27.1s
# 50:	learn: 0.9664941	test: 0.9648743	best: 0.9648743 (50)	total: 1.57s	remaining: 29.3s
# 60:	learn: 0.9681252	test: 0.9654652	best: 0.9655628 (59)	total: 1.85s	remaining: 28.5s
# 70:	learn: 0.9685730	test: 0.9654326	best: 0.9655628 (59)	total: 2.13s	remaining: 27.8s
# 80:	learn: 0.9696712	test: 0.9661498	best: 0.9661562 (78)	total: 2.39s	remaining: 27.2s
# 90:	learn: 0.9701239	test: 0.9657262	best: 0.9663325 (81)	total: 2.65s	remaining: 26.5s
# 100:	learn: 0.9706689	test: 0.9651053	best: 0.9663325 (81)	total: 2.91s	remaining: 25.9s
# 110:	learn: 0.9708986	test: 0.9648823	best: 0.9663325 (81)	total: 3.21s	remaining: 25.8s
# 120:	learn: 0.9714069	test: 0.9647640	best: 0.9663325 (81)	total: 3.5s	remaining: 25.4s
# 130:	learn: 0.9717289	test: 0.9643773	best: 0.9663325 (81)	total: 3.78s	remaining: 25.1s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.9663325137
# bestIteration = 81
#
# Shrink model to first 82 iterations.
# Validation f1 0.7419738449323212
# Learning rate set to 0.057696
# 0:	learn: 0.9559830	test: 0.9549298	best: 0.9549298 (0)	total: 28.3ms	remaining: 28.2s
# 10:	learn: 0.9613606	test: 0.9565056	best: 0.9572252 (6)	total: 297ms	remaining: 26.7s
# 20:	learn: 0.9644499	test: 0.9581820	best: 0.9582712 (19)	total: 576ms	remaining: 26.9s
# 30:	learn: 0.9645723	test: 0.9584498	best: 0.9587100 (24)	total: 865ms	remaining: 27s
# 40:	learn: 0.9655983	test: 0.9594179	best: 0.9594254 (39)	total: 1.15s	remaining: 26.9s
# 50:	learn: 0.9675383	test: 0.9601195	best: 0.9601195 (47)	total: 1.45s	remaining: 26.9s
# 60:	learn: 0.9687987	test: 0.9611823	best: 0.9611823 (60)	total: 1.73s	remaining: 26.7s
# 70:	learn: 0.9694880	test: 0.9610924	best: 0.9616320 (66)	total: 1.99s	remaining: 26.1s
# 80:	learn: 0.9704937	test: 0.9619021	best: 0.9619021 (80)	total: 2.28s	remaining: 25.9s
# 90:	learn: 0.9709960	test: 0.9621723	best: 0.9621723 (89)	total: 2.56s	remaining: 25.6s
# 100:	learn: 0.9717316	test: 0.9621723	best: 0.9621723 (89)	total: 2.88s	remaining: 25.6s
# 110:	learn: 0.9724249	test: 0.9622624	best: 0.9627061 (107)	total: 3.15s	remaining: 25.2s
# 120:	learn: 0.9727449	test: 0.9622624	best: 0.9627061 (107)	total: 3.49s	remaining: 25.4s
# 130:	learn: 0.9731165	test: 0.9620822	best: 0.9627061 (107)	total: 3.89s	remaining: 25.8s
# 140:	learn: 0.9735344	test: 0.9621723	best: 0.9627061 (107)	total: 4.21s	remaining: 25.7s
# 150:	learn: 0.9739502	test: 0.9623525	best: 0.9627061 (107)	total: 4.49s	remaining: 25.3s
# 160:	learn: 0.9747803	test: 0.9629838	best: 0.9629838 (160)	total: 4.78s	remaining: 24.9s
# 170:	learn: 0.9753802	test: 0.9629838	best: 0.9629838 (160)	total: 5.06s	remaining: 24.6s
# 180:	learn: 0.9758068	test: 0.9629838	best: 0.9630740 (172)	total: 5.36s	remaining: 24.2s
# 190:	learn: 0.9758927	test: 0.9625187	best: 0.9630740 (172)	total: 5.65s	remaining: 23.9s
# 200:	learn: 0.9762177	test: 0.9624356	best: 0.9630740 (172)	total: 5.94s	remaining: 23.6s
# 210:	learn: 0.9767287	test: 0.9627894	best: 0.9630740 (172)	total: 6.23s	remaining: 23.3s
# 220:	learn: 0.9773799	test: 0.9630533	best: 0.9630740 (172)	total: 6.52s	remaining: 23s
# 230:	learn: 0.9779811	test: 0.9630463	best: 0.9632408 (227)	total: 6.82s	remaining: 22.7s
# 240:	learn: 0.9783583	test: 0.9631436	best: 0.9632408 (227)	total: 7.12s	remaining: 22.4s
# 250:	learn: 0.9786869	test: 0.9632339	best: 0.9632408 (227)	total: 7.43s	remaining: 22.2s
# 260:	learn: 0.9790136	test: 0.9632339	best: 0.9633243 (258)	total: 7.74s	remaining: 21.9s
# 270:	learn: 0.9792939	test: 0.9630463	best: 0.9633243 (258)	total: 8.03s	remaining: 21.6s
# 280:	learn: 0.9795295	test: 0.9632270	best: 0.9633243 (258)	total: 8.34s	remaining: 21.3s
# 290:	learn: 0.9798568	test: 0.9633174	best: 0.9633243 (258)	total: 8.63s	remaining: 21s
# 300:	learn: 0.9799971	test: 0.9634146	best: 0.9634146 (300)	total: 8.93s	remaining: 20.7s
# 310:	learn: 0.9801394	test: 0.9634982	best: 0.9634982 (305)	total: 9.25s	remaining: 20.5s
# 320:	learn: 0.9801843	test: 0.9633243	best: 0.9634982 (305)	total: 9.54s	remaining: 20.2s
# 330:	learn: 0.9803734	test: 0.9632339	best: 0.9634982 (305)	total: 9.83s	remaining: 19.9s
# 340:	learn: 0.9806076	test: 0.9631436	best: 0.9634982 (305)	total: 10.1s	remaining: 19.6s
# 350:	learn: 0.9806544	test: 0.9632339	best: 0.9634982 (305)	total: 10.4s	remaining: 19.3s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.9634981702
# bestIteration = 305
#
# Shrink model to first 306 iterations.
# Validation f1 0.6838930361037853

# %%
np.mean(validation_scores), np.std(validation_scores)
# Out:
# (0.7080453978876703, 0.02469850158496203)
