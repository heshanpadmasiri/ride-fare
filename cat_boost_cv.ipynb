# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score

from catboost import Pool, cv,CatBoostClassifier

# %%
train_df = pd.read_csv('train_df.csv')
test_df = pd.read_csv('test_df.csv')
submission_df = pd.read_csv('sample_submission.csv')

# %%
train_df.head()
# Out:
#    additional_fare  duration  meter_waiting  meter_waiting_fare  \
# 0             10.5     834.0           56.0              0.0000
# 1             10.5     791.0           47.0              0.0000
# 2             10.5    1087.0           80.0              0.0000
# 3             10.5     598.0          271.0             15.6638
# 4             10.5    3407.0          182.0              0.0000
#
#    meter_waiting_till_pickup  pick_lat  pick_lon  drop_lat  drop_lon     fare  \
# 0                       64.0   6.86252   79.8993   6.90330   79.8783   270.32
# 1                      134.0   6.88589   79.8984   6.91373   79.8923   197.85
# 2                       61.0   6.90839   79.8651   6.93669   79.9146   301.64
# 3                       68.0   6.92570   79.8895   6.92748   79.8971    82.30
# 4                      112.0   7.13402   79.8969   6.91865   79.8649  1065.02
#
#    pickup_date  pickup_year  pickup_hour  pickup_minute  drop_date  drop_year  \
# 0            1         2019            0             20          1       2019
# 1            1         2019            0             56          1       2019
# 2            1         2019            1              8          1       2019
# 3            1         2019            2             27          1       2019
# 4            1         2019            5             38          1       2019
#
#    drop_hour  drop_minute  label
# 0          0           34      0
# 1          1            9      0
# 2          1           26      0
# 3          2           37      0
# 4          6           35      0

# %%
features = ['additional_fare', 'duration', 'meter_waiting', 'meter_waiting_fare',
       'meter_waiting_till_pickup', 'pick_lat', 'pick_lon', 'drop_lat',
       'drop_lon', 'fare', 'pickup_date', 'pickup_year', 'pickup_hour',
       'pickup_minute', 'drop_date', 'drop_year', 'drop_hour', 'drop_minute']
cat_features = ['pickup_date', 'pickup_year', 'pickup_hour',
       'pickup_minute', 'drop_date', 'drop_year', 'drop_hour', 'drop_minute']
labels = train_df['label'].values
train_df = train_df.drop(['label'], axis=1)

# %%
skf = StratifiedKFold(n_splits=5)

# %%
params = {
    'loss_function':'Logloss',
    'random_state':0,
    'early_stopping_rounds':50,
    'cat_features':cat_features,
    'eval_metric':'F1'
}

# %%
validation_scores = []

# %%
for train_index, test_index in skf.split(train_df, labels):
    X_train, X_test = train_df.iloc[train_index,:], train_df.iloc[test_index,:]
    y_train, y_test = labels[train_index], labels[test_index]
    train_pool = Pool(data=X_train, label=y_train,cat_features=cat_features)
    test_pool = Pool(data=X_test, label=y_test, cat_features=cat_features)
    
    model = CatBoostClassifier(**params)
    model.fit(X=train_pool, eval_set=test_pool,verbose=10)
    pred = model.predict(test_pool)
    validation_score = f1_score(y_test, pred, average='macro')
    print('Validation f1',validation_score)
    validation_scores.append(validation_score)
# Out:
# Learning rate set to 0.06035
# 0:	learn: 0.3092917	test: 0.2936709	best: 0.2936709 (0)	total: 22.6ms	remaining: 22.6s
# 10:	learn: 0.2565556	test: 0.2808989	best: 0.3038674 (4)	total: 167ms	remaining: 15s
# 20:	learn: 0.3055747	test: 0.3215259	best: 0.3215259 (20)	total: 317ms	remaining: 14.8s
# 30:	learn: 0.3678312	test: 0.4183673	best: 0.4263959 (29)	total: 445ms	remaining: 13.9s
# 40:	learn: 0.4135290	test: 0.4668305	best: 0.4679803 (36)	total: 585ms	remaining: 13.7s
# 50:	learn: 0.4480398	test: 0.4854369	best: 0.5000000 (45)	total: 714ms	remaining: 13.3s
# 60:	learn: 0.4858006	test: 0.5270588	best: 0.5270588 (59)	total: 854ms	remaining: 13.1s
# 70:	learn: 0.5138807	test: 0.5429234	best: 0.5441860 (67)	total: 974ms	remaining: 12.7s
# 80:	learn: 0.5273574	test: 0.5714286	best: 0.5746606 (78)	total: 1.11s	remaining: 12.7s
# 90:	learn: 0.5377957	test: 0.5778781	best: 0.5778781 (83)	total: 1.24s	remaining: 12.4s
# 100:	learn: 0.5503432	test: 0.5874439	best: 0.5874439 (98)	total: 1.39s	remaining: 12.4s
# 110:	learn: 0.5715896	test: 0.6048565	best: 0.6048565 (110)	total: 1.51s	remaining: 12.1s
# 120:	learn: 0.5787998	test: 0.6109890	best: 0.6109890 (115)	total: 1.65s	remaining: 12s
# 130:	learn: 0.5887590	test: 0.6113537	best: 0.6126915 (122)	total: 1.77s	remaining: 11.7s
# 140:	learn: 0.5980066	test: 0.6173913	best: 0.6203905 (139)	total: 1.91s	remaining: 11.6s
# 150:	learn: 0.6099835	test: 0.6293103	best: 0.6293103 (150)	total: 2.05s	remaining: 11.6s
# 160:	learn: 0.6224157	test: 0.6381156	best: 0.6381156 (159)	total: 2.21s	remaining: 11.5s
# 170:	learn: 0.6290672	test: 0.6439232	best: 0.6439232 (170)	total: 2.35s	remaining: 11.4s
# 180:	learn: 0.6375405	test: 0.6496815	best: 0.6525424 (176)	total: 2.61s	remaining: 11.8s
# 190:	learn: 0.6510139	test: 0.6553911	best: 0.6582278 (187)	total: 2.79s	remaining: 11.8s
# 200:	learn: 0.6638478	test: 0.6610526	best: 0.6638655 (197)	total: 2.93s	remaining: 11.7s
# 210:	learn: 0.6698262	test: 0.6624738	best: 0.6638655 (197)	total: 3.06s	remaining: 11.5s
# 220:	learn: 0.6857143	test: 0.6666667	best: 0.6680585 (216)	total: 3.21s	remaining: 11.3s
# 230:	learn: 0.6921883	test: 0.6694387	best: 0.6721992 (225)	total: 3.34s	remaining: 11.1s
# 240:	learn: 0.6976264	test: 0.6666667	best: 0.6721992 (225)	total: 3.48s	remaining: 11s
# 250:	learn: 0.7049769	test: 0.6694387	best: 0.6721992 (225)	total: 3.62s	remaining: 10.8s
# 260:	learn: 0.7159612	test: 0.6708075	best: 0.6735537 (258)	total: 3.78s	remaining: 10.7s
# 270:	learn: 0.7224759	test: 0.6762887	best: 0.6762887 (269)	total: 3.92s	remaining: 10.5s
# 280:	learn: 0.7286508	test: 0.6708075	best: 0.6762887 (269)	total: 4.08s	remaining: 10.4s
# 290:	learn: 0.7334004	test: 0.6735537	best: 0.6762887 (269)	total: 4.21s	remaining: 10.2s
# 300:	learn: 0.7405921	test: 0.6762887	best: 0.6762887 (269)	total: 4.37s	remaining: 10.1s
# 310:	learn: 0.7461347	test: 0.6748971	best: 0.6762887 (269)	total: 4.5s	remaining: 9.96s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6762886598
# bestIteration = 269
#
# Shrink model to first 270 iterations.
# Validation f1 0.8256938937351309
# Learning rate set to 0.060351
# 0:	learn: 0.2720733	test: 0.2500000	best: 0.2500000 (0)	total: 13.2ms	remaining: 13.1s
# 10:	learn: 0.2318215	test: 0.2413793	best: 0.2507123 (5)	total: 159ms	remaining: 14.3s
# 20:	learn: 0.2625265	test: 0.2785515	best: 0.2785515 (20)	total: 287ms	remaining: 13.4s
# 30:	learn: 0.3629139	test: 0.4143223	best: 0.4143223 (30)	total: 482ms	remaining: 15.1s
# 40:	learn: 0.4183090	test: 0.4668305	best: 0.4668305 (40)	total: 708ms	remaining: 16.6s
# 50:	learn: 0.4665439	test: 0.4798100	best: 0.4892086 (48)	total: 861ms	remaining: 16s
# 60:	learn: 0.4988038	test: 0.5069767	best: 0.5150812 (58)	total: 1s	remaining: 15.5s
# 70:	learn: 0.5199531	test: 0.5248869	best: 0.5248869 (70)	total: 1.13s	remaining: 14.8s
# 80:	learn: 0.5409458	test: 0.5401786	best: 0.5466667 (78)	total: 1.29s	remaining: 14.7s
# 90:	learn: 0.5526316	test: 0.5442478	best: 0.5498891 (83)	total: 1.42s	remaining: 14.2s
# 100:	learn: 0.5643059	test: 0.5570175	best: 0.5601751 (98)	total: 1.58s	remaining: 14.1s
# 110:	learn: 0.5775042	test: 0.5738758	best: 0.5806452 (108)	total: 1.73s	remaining: 13.9s
# 120:	learn: 0.5943553	test: 0.5787234	best: 0.5806452 (108)	total: 1.91s	remaining: 13.9s
# 130:	learn: 0.6008820	test: 0.5787234	best: 0.5817410 (129)	total: 2.08s	remaining: 13.8s
# 140:	learn: 0.6096491	test: 0.5822785	best: 0.5847458 (132)	total: 2.27s	remaining: 13.8s
# 150:	learn: 0.6179837	test: 0.5852632	best: 0.5852632 (142)	total: 2.44s	remaining: 13.7s
# 160:	learn: 0.6273661	test: 0.5857741	best: 0.5870021 (158)	total: 2.66s	remaining: 13.9s
# 170:	learn: 0.6387996	test: 0.5916667	best: 0.5916667 (169)	total: 2.84s	remaining: 13.8s
# 180:	learn: 0.6582145	test: 0.5962733	best: 0.5962733 (178)	total: 3.03s	remaining: 13.7s
# 190:	learn: 0.6684128	test: 0.6078029	best: 0.6078029 (190)	total: 3.23s	remaining: 13.7s
# 200:	learn: 0.6750130	test: 0.6134969	best: 0.6134969 (199)	total: 3.41s	remaining: 13.6s
# 210:	learn: 0.6805195	test: 0.6138211	best: 0.6150713 (201)	total: 3.58s	remaining: 13.4s
# 220:	learn: 0.6866598	test: 0.6150713	best: 0.6150713 (201)	total: 3.77s	remaining: 13.3s
# 230:	learn: 0.6981035	test: 0.6206897	best: 0.6219512 (223)	total: 3.93s	remaining: 13.1s
# 240:	learn: 0.7043833	test: 0.6237425	best: 0.6237425 (238)	total: 4.11s	remaining: 12.9s
# 250:	learn: 0.7086934	test: 0.6265060	best: 0.6265060 (243)	total: 4.3s	remaining: 12.8s
# 260:	learn: 0.7142857	test: 0.6307385	best: 0.6320000 (257)	total: 4.48s	remaining: 12.7s
# 270:	learn: 0.7171717	test: 0.6388889	best: 0.6388889 (267)	total: 4.66s	remaining: 12.5s
# 280:	learn: 0.7259036	test: 0.6361829	best: 0.6388889 (267)	total: 4.85s	remaining: 12.4s
# 290:	learn: 0.7296352	test: 0.6387226	best: 0.6388889 (267)	total: 5.02s	remaining: 12.2s
# 300:	learn: 0.7335329	test: 0.6415842	best: 0.6442688 (295)	total: 5.23s	remaining: 12.2s
# 310:	learn: 0.7391521	test: 0.6442688	best: 0.6442688 (295)	total: 5.42s	remaining: 12s
# 320:	learn: 0.7445328	test: 0.6428571	best: 0.6455446 (312)	total: 5.61s	remaining: 11.9s
# 330:	learn: 0.7522299	test: 0.6428571	best: 0.6455446 (312)	total: 5.78s	remaining: 11.7s
# 340:	learn: 0.7570510	test: 0.6415842	best: 0.6455446 (312)	total: 5.96s	remaining: 11.5s
# 350:	learn: 0.7587568	test: 0.6429980	best: 0.6455446 (312)	total: 6.14s	remaining: 11.4s
# 360:	learn: 0.7659158	test: 0.6496063	best: 0.6496063 (358)	total: 6.33s	remaining: 11.2s
# 370:	learn: 0.7683284	test: 0.6509804	best: 0.6509804 (370)	total: 6.5s	remaining: 11s
# 380:	learn: 0.7706601	test: 0.6483301	best: 0.6536204 (374)	total: 6.69s	remaining: 10.9s
# 390:	learn: 0.7785888	test: 0.6483301	best: 0.6536204 (374)	total: 6.88s	remaining: 10.7s
# 400:	learn: 0.7801556	test: 0.6496063	best: 0.6536204 (374)	total: 7.12s	remaining: 10.6s
# 410:	learn: 0.7801556	test: 0.6417323	best: 0.6536204 (374)	total: 7.42s	remaining: 10.6s
# 420:	learn: 0.7844660	test: 0.6417323	best: 0.6536204 (374)	total: 7.59s	remaining: 10.4s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6536203523
# bestIteration = 374
#
# Shrink model to first 375 iterations.
# Validation f1 0.8127110842023515
# Learning rate set to 0.060353
# 0:	learn: 0.3249001	test: 0.3138298	best: 0.3138298 (0)	total: 15.7ms	remaining: 15.7s
# 10:	learn: 0.2026432	test: 0.1611940	best: 0.3138298 (0)	total: 187ms	remaining: 16.8s
# 20:	learn: 0.3496316	test: 0.2958904	best: 0.3138298 (0)	total: 447ms	remaining: 20.8s
# 30:	learn: 0.3942931	test: 0.3225806	best: 0.3404255 (26)	total: 697ms	remaining: 21.8s
# 40:	learn: 0.4429195	test: 0.3701799	best: 0.3804627 (36)	total: 896ms	remaining: 20.9s
# 50:	learn: 0.4960961	test: 0.4049383	best: 0.4049383 (49)	total: 1.08s	remaining: 20.2s
# 60:	learn: 0.5153302	test: 0.4029126	best: 0.4146341 (52)	total: 1.25s	remaining: 19.3s
# 70:	learn: 0.5379710	test: 0.4323040	best: 0.4323040 (70)	total: 1.45s	remaining: 19s
# 80:	learn: 0.5608646	test: 0.4543326	best: 0.4615385 (73)	total: 1.62s	remaining: 18.4s
# 90:	learn: 0.5736872	test: 0.4547564	best: 0.4615385 (73)	total: 1.81s	remaining: 18.1s
# 100:	learn: 0.5898720	test: 0.4562212	best: 0.4615385 (73)	total: 1.97s	remaining: 17.6s
# 110:	learn: 0.6011050	test: 0.4587156	best: 0.4633028 (106)	total: 2.15s	remaining: 17.2s
# 120:	learn: 0.6085526	test: 0.4772727	best: 0.4772727 (120)	total: 2.31s	remaining: 16.8s
# 130:	learn: 0.6161396	test: 0.4740406	best: 0.4772727 (120)	total: 2.5s	remaining: 16.6s
# 140:	learn: 0.6273661	test: 0.4843049	best: 0.4853933 (134)	total: 2.68s	remaining: 16.3s
# 150:	learn: 0.6420150	test: 0.4832215	best: 0.4876957 (146)	total: 2.88s	remaining: 16.2s
# 160:	learn: 0.6474359	test: 0.4910714	best: 0.4910714 (157)	total: 3.05s	remaining: 15.9s
# 170:	learn: 0.6492537	test: 0.4944321	best: 0.4944321 (167)	total: 3.25s	remaining: 15.7s
# 180:	learn: 0.6642066	test: 0.5121413	best: 0.5121413 (172)	total: 3.44s	remaining: 15.6s
# 190:	learn: 0.6729461	test: 0.5260870	best: 0.5260870 (188)	total: 3.63s	remaining: 15.4s
# 200:	learn: 0.6805628	test: 0.5185185	best: 0.5260870 (188)	total: 3.83s	remaining: 15.2s
# 210:	learn: 0.6924266	test: 0.5310493	best: 0.5321888 (209)	total: 3.99s	remaining: 14.9s
# 220:	learn: 0.6985105	test: 0.5435244	best: 0.5446809 (218)	total: 4.19s	remaining: 14.8s
# 230:	learn: 0.7061224	test: 0.5515789	best: 0.5539112 (227)	total: 4.37s	remaining: 14.5s
# 240:	learn: 0.7126904	test: 0.5515789	best: 0.5539112 (227)	total: 4.57s	remaining: 14.4s
# 250:	learn: 0.7192716	test: 0.5546218	best: 0.5557895 (243)	total: 4.75s	remaining: 14.2s
# 260:	learn: 0.7237903	test: 0.5557895	best: 0.5557895 (243)	total: 4.95s	remaining: 14s
# 270:	learn: 0.7282772	test: 0.5606695	best: 0.5618449 (267)	total: 5.12s	remaining: 13.8s
# 280:	learn: 0.7347347	test: 0.5660377	best: 0.5660377 (280)	total: 5.33s	remaining: 13.6s
# 290:	learn: 0.7387836	test: 0.5618449	best: 0.5660377 (280)	total: 5.5s	remaining: 13.4s
# 300:	learn: 0.7445328	test: 0.5606695	best: 0.5660377 (280)	total: 5.71s	remaining: 13.3s
# 310:	learn: 0.7480159	test: 0.5618449	best: 0.5660377 (280)	total: 5.88s	remaining: 13s
# 320:	learn: 0.7519763	test: 0.5606695	best: 0.5660377 (280)	total: 6.08s	remaining: 12.9s
# 330:	learn: 0.7582472	test: 0.5648536	best: 0.5660377 (280)	total: 6.25s	remaining: 12.6s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.5660377358
# bestIteration = 280
#
# Shrink model to first 281 iterations.
# Validation f1 0.7666137324038436
# Learning rate set to 0.060353
# 0:	learn: 0.3075890	test: 0.3856041	best: 0.3856041 (0)	total: 18.3ms	remaining: 18.3s
# 10:	learn: 0.2167273	test: 0.2564103	best: 0.3856041 (0)	total: 182ms	remaining: 16.4s
# 20:	learn: 0.2890896	test: 0.2801120	best: 0.3856041 (0)	total: 324ms	remaining: 15.1s
# 30:	learn: 0.3807040	test: 0.3607427	best: 0.3856041 (0)	total: 504ms	remaining: 15.8s
# 40:	learn: 0.4425000	test: 0.3938619	best: 0.3938619 (40)	total: 691ms	remaining: 16.2s
# 50:	learn: 0.4700122	test: 0.4246914	best: 0.4334975 (47)	total: 930ms	remaining: 17.3s
# 60:	learn: 0.4969988	test: 0.4590164	best: 0.4604651 (55)	total: 1.13s	remaining: 17.4s
# 70:	learn: 0.5284124	test: 0.4770642	best: 0.4770642 (70)	total: 1.39s	remaining: 18.2s
# 80:	learn: 0.5524798	test: 0.4844444	best: 0.4844444 (80)	total: 1.56s	remaining: 17.7s
# 90:	learn: 0.5774011	test: 0.5065502	best: 0.5065502 (88)	total: 1.85s	remaining: 18.5s
# 100:	learn: 0.5844083	test: 0.5178947	best: 0.5183585 (99)	total: 2.11s	remaining: 18.8s
# 110:	learn: 0.5998887	test: 0.5173116	best: 0.5224490 (105)	total: 2.42s	remaining: 19.4s
# 120:	learn: 0.6092715	test: 0.5183752	best: 0.5224490 (105)	total: 2.66s	remaining: 19.3s
# 130:	learn: 0.6208402	test: 0.5121495	best: 0.5224490 (105)	total: 2.85s	remaining: 18.9s
# 140:	learn: 0.6345946	test: 0.5158879	best: 0.5224490 (105)	total: 3.11s	remaining: 18.9s
# 150:	learn: 0.6375405	test: 0.5157699	best: 0.5224490 (105)	total: 3.4s	remaining: 19.1s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.5224489796
# bestIteration = 105
#
# Shrink model to first 106 iterations.
# Validation f1 0.7426412623499209
# Learning rate set to 0.060353
# 0:	learn: 0.3348776	test: 0.2747253	best: 0.2747253 (0)	total: 23.6ms	remaining: 23.6s
# 10:	learn: 0.2375810	test: 0.0511182	best: 0.2747253 (0)	total: 171ms	remaining: 15.3s
# 20:	learn: 0.3633952	test: 0.1556886	best: 0.2747253 (0)	total: 336ms	remaining: 15.6s
# 30:	learn: 0.4133504	test: 0.1812865	best: 0.2747253 (0)	total: 529ms	remaining: 16.5s
# 40:	learn: 0.4641975	test: 0.2707182	best: 0.2747253 (0)	total: 739ms	remaining: 17.3s
# 50:	learn: 0.4857316	test: 0.2942779	best: 0.2942779 (49)	total: 914ms	remaining: 17s
# 60:	learn: 0.5166271	test: 0.3064516	best: 0.3155080 (58)	total: 1.09s	remaining: 16.9s
# 70:	learn: 0.5497685	test: 0.3208556	best: 0.3208556 (68)	total: 1.29s	remaining: 16.9s
# 80:	learn: 0.5809363	test: 0.3532468	best: 0.3532468 (80)	total: 1.51s	remaining: 17.2s
# 90:	learn: 0.5914703	test: 0.3541667	best: 0.3575130 (82)	total: 1.79s	remaining: 17.9s
# 100:	learn: 0.6048835	test: 0.3626943	best: 0.3626943 (98)	total: 1.99s	remaining: 17.7s
# 110:	learn: 0.6183416	test: 0.3617571	best: 0.3669251 (101)	total: 2.27s	remaining: 18.2s
# 120:	learn: 0.6232914	test: 0.3617571	best: 0.3669251 (101)	total: 2.49s	remaining: 18.1s
# 130:	learn: 0.6315217	test: 0.3692308	best: 0.3743590 (122)	total: 2.67s	remaining: 17.7s
# 140:	learn: 0.6404313	test: 0.3775510	best: 0.3775510 (135)	total: 2.87s	remaining: 17.5s
# 150:	learn: 0.6560170	test: 0.3848101	best: 0.3848101 (147)	total: 3.12s	remaining: 17.5s
# 160:	learn: 0.6694826	test: 0.3888889	best: 0.3929471 (153)	total: 3.34s	remaining: 17.4s
# 170:	learn: 0.6771654	test: 0.3929471	best: 0.3929471 (153)	total: 3.51s	remaining: 17s
# 180:	learn: 0.6830287	test: 0.4010025	best: 0.4010025 (177)	total: 3.7s	remaining: 16.8s
# 190:	learn: 0.6878914	test: 0.4010025	best: 0.4010025 (177)	total: 3.86s	remaining: 16.4s
# 200:	learn: 0.6915888	test: 0.4050000	best: 0.4050000 (198)	total: 4.05s	remaining: 16.1s
# 210:	learn: 0.6966408	test: 0.4050000	best: 0.4089776 (201)	total: 4.21s	remaining: 15.8s
# 220:	learn: 0.7070915	test: 0.3990025	best: 0.4089776 (201)	total: 4.39s	remaining: 15.5s
# 230:	learn: 0.7126789	test: 0.3909774	best: 0.4089776 (201)	total: 4.62s	remaining: 15.4s
# 240:	learn: 0.7166922	test: 0.3990025	best: 0.4089776 (201)	total: 4.83s	remaining: 15.2s
# 250:	learn: 0.7232960	test: 0.3990025	best: 0.4089776 (201)	total: 5.03s	remaining: 15s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4089775561
# bestIteration = 201
#
# Shrink model to first 202 iterations.
# Validation f1 0.6859296551104618

# %%
np.mean(validation_scores), np.std(validation_scores)
# Out:
# (0.7667179255603418, 0.050398366389929075)
